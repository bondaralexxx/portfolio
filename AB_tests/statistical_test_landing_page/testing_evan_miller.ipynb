# %%
import pandas as pd
import numpy as np

# %%
"https://www.evanmiller.org/ab-testing/sample-size.html"
# Baseline conversion rate: 3%
# MDE: 2%
# power: 80%
# Significance level: 5%
# calculated sample size according to Evan Miller's calculator:
samle_size = 1245

# %%
def test(conv_a,conv_b,size_a,size_b,significance=0.05):
  _, p_value = proportions_ztest([conv_a, conv_b],
                                 [size_a, size_b],
                                 alternative='two-sided')
  return p_value < significance

# %%
# TRP (Sensitivity) testing

# %%
from statsmodels.stats.proportion import proportions_ztest

# %%
n = 10000
result = []
for i in range(n):
  a = np.random.binomial(samle_size,0.03)
  b = np.random.binomial(samle_size,0.05)
  result.append((a,b))

# %%
df = pd.DataFrame(result, columns=['a','b'])

# %%
#   table with 10000 experiments

# %%
df
# Out:
#        a   b
# 0     39  52
# 1     42  68
# 2     41  69
# 3     32  64
# 4     42  54
# ...   ..  ..
# 9995  25  71
# 9996  34  74
# 9997  35  63
# 9998  39  64
# 9999  39  65
#
# [10000 rows x 2 columns]

# %%
df.apply(lambda row: test(row['a'],row['b'],samle_size,samle_size),axis=1)
# Out:
# 0       False
# 1        True
# 2        True
# 3        True
# 4       False
#         ...
# 9995     True
# 9996     True
# 9997     True
# 9998     True
# 9999     True
# Length: 10000, dtype: bool

# %%
df['test'] = df.apply(lambda row: test(row['a'],row['b'],samle_size,samle_size),axis=1)

# %%
df
# Out:
#        a   b   test
# 0     39  52  False
# 1     42  68   True
# 2     41  69   True
# 3     32  64   True
# 4     42  54  False
# ...   ..  ..    ...
# 9995  25  71   True
# 9996  34  74   True
# 9997  35  63   True
# 9998  39  64   True
# 9999  39  65   True
#
# [10000 rows x 3 columns]

# %%
df['test'].mean()
# Out:
# 0.7185

# %%
# FPR|

# %%
n = 10000
result = []
for i in range(n):
  a = np.random.binomial(samle_size,0.03)
  b = np.random.binomial(samle_size,0.03)
  result.append((a,b))

# %%
df = pd.DataFrame(result, columns=['a','b'])

# %%
#   table with 10000 experiments

# %%
df
# Out:
#        a   b
# 0     35  35
# 1     35  41
# 2     38  27
# 3     39  50
# 4     36  30
# ...   ..  ..
# 9995  33  33
# 9996  45  34
# 9997  30  33
# 9998  35  39
# 9999  43  34
#
# [10000 rows x 2 columns]

# %%
df.apply(lambda row: test(row['a'],row['b'],samle_size,samle_size),axis=1)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Length: 10000, dtype: bool

# %%
df['test'] = df.apply(lambda row: test(row['a'],row['b'],samle_size,samle_size),axis=1)

# %%
df
# Out:
#        a   b   test
# 0     35  35  False
# 1     35  41  False
# 2     38  27  False
# 3     39  50  False
# 4     36  30  False
# ...   ..  ..    ...
# 9995  33  33  False
# 9996  45  34  False
# 9997  30  33  False
# 9998  35  39  False
# 9999  43  34  False
#
# [10000 rows x 3 columns]

# %%
df['test'].mean()
# Out:
# 0.0504

# %%
#  the given sample size does note give the desired TRP
